# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajulearner/FeatureSelection-/blob/master/Feature_Selection_with_filtering_method_%7C_Constant%2C_Quasi_Constant_and_Duplicate_feature_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle/ #as per the doc creating folder

# %%
# !cp kaggle.json ~/.kaggle/ #copying file--kaggle.josn to that folder

# %%
# !chmod 600 ~/.kaggle/kaggle.json #chmod will helps us to save our data securly

# %%
# !kaggle competitions download -c santander-customer-satisfaction #search the kaggle dataset, and copy the data as 
#like above it will dwld files in left section.
# Out:
# ...
#   0% 0.00/4.05M [00:00<?, ?B/s]
# 100% 4.05M/4.05M [00:00<00:00, 136MB/s]
# ...
#   0% 0.00/4.02M [00:00<?, ?B/s]
# 100% 4.02M/4.02M [00:00<00:00, 132MB/s]
# ...
#   0% 0.00/612k [00:00<?, ?B/s]
# 100% 612k/612k [00:00<00:00, 83.3MB/s]

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2>Filtering method:</h2>
#
# Unnecessary and redundant features not only slow down the training time of an algorithm, but they also affect the performance of the algorithm.
#
# There are several advantages of performing feature selection before training machine learning models:
#
# Models with less number of features have higher explainability.
# It is easier to implement machine learning models with reduced features.
# Fewer features lead to enhanced generalization which in turn reduces overfitting.
# Feature selection removes data redundancy.
# Training time of models with fewer features is significantly lower.
# Models with fewer features are less prone to errors.
# What is filter method?
# Features selected using filter methods can be used as an input to any machine learning models.
#
# <b>Univariate </b>-> Fisher Score, Mutual Information Gain, Variance etc
# Multi-variate -> Pearson Correlation
# The univariate filter methods are the type of methods where individual features are ranked according to specific criteria. The top N features are then selected. Different types of ranking criteria are used for univariate filtermethods, for example fisher score, mutual information, and variance of the feature.
#
# <b>Multivariate filter methods</b> are capable of removing redundant features from the data since they take the mutual relationship between the features into account.

# %%
df=pd.read_csv('train.csv.zip')
df
# Out:
#            ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0           1     2     23  ...                     0.0   39205.170000       0
# 1           3     2     34  ...                     0.0   49278.030000       0
# 2           4     2     23  ...                     0.0   67333.770000       0
# 3           8     2     37  ...                     0.0   64007.970000       0
# 4          10     2     39  ...                     0.0  117310.979016       0
# ...       ...   ...    ...  ...                     ...            ...     ...
# 76015  151829     2     48  ...                     0.0   60926.490000       0
# 76016  151830     2     39  ...                     0.0  118634.520000       0
# 76017  151835     2     23  ...                     0.0   74028.150000       0
# 76018  151836     2     25  ...                     0.0   84278.160000       0
# 76019  151838     2     46  ...                     0.0  117310.979016       0
#
# ...

# %% [markdown]
# <b>Univariate Filtering Methods:</b><br><hr>
# Constant Removal<br>
# Quasi Constant Removal<br>
# Duplicate Feature Removal<br>

# %% [markdown]
# **Constant Feature Removal**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import VarianceThreshold
'''This feature selection algorithm looks only at the features (X), not the desired outputs (y), 
and can thus be used for unsupervised learning.'''
#ref : https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html
# Out:
# 'This feature selection algorithm looks only at the features (X), not the desired outputs (y), \nand can thus be used for unsupervised learning.'

# %%
df.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
x=df.drop('TARGET',axis=1)
y=df['TARGET']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0,stratify=y)

# %%
##

# %% [markdown]
# **Constant** **filter** **Removal**

# %%
constant_filter = VarianceThreshold(threshold=50)
constant_filter.fit(x_train)
# Out:
# VarianceThreshold(threshold=50)

# %%
constant_filter.get_support().sum()
# Out:
# 149
